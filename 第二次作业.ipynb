# %%
1.总结`name_scope`与`variable_scope`的作用以及异同点。
（1）name_scope`可以为其作用域中的节点的`name`添加一个或多个前缀，
并使用这些前缀作为划分内部与外部`op`范围的标记。
（2）variable_scope`主要用于管理变量作用域以及与变量相关的操作，
同时`variable_scope`也可以像`name_scope`一样用来给不同操作
区域划分范围（添加`name`前缀）。`variable_scope`功能也要更
丰富，最重要的是可以与`tf.get_variable()`等配合使用完成对
变量的重复使用。
（3）
不同：
a、name_scope不能与tf.get_variable()配合使用，而
variable_scope可以
b、variable_scope功能更丰富
相同：
a、都可以用来给不同操作区域划分范围
b、默认的`variable_scope`的`name`等于其对应的`name_scope`
的`name`，但并不总是这样。

# %%
2.构建逻辑回归模型（只有模型部分，不包括训练部分），
使用`get_variable`与`variable_scope`将变量的创建与使用
分开。提示：使用`tf.nn.sigmoid`实现`logistic`函数。

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
with tf.variable_scope('my_scope',reuse = None):
    x = tf.get_variable('var', shape=[])
    y = tf.nn.sigmoid(x)
    data = np.linspace(-5, 5, 100)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    y_sigmoid = sess.run(y,feed_dict={x:data})

fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(121)
ax.plot(data,y_sigmoid)
ax.grid()
ax.set_title('(a) Sigmoid')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-bf347f992873> in <module>()
#       3 import numpy as np
#       4 with tf.variable_scope('my_scope',reuse = None):
# ----> 5     x = tf.get_variable('var',dtype=tf.float32, shape=[])
#       6     y = tf.nn.sigmoid(x)
#       7     data = np.linspace(-5, 5, 100)
#
# D:\anaconda\anaconda\lib\site-packages\tensorflow\python\ops\variable_scope.py in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1482       constraint=constraint,
#    1483       synchronization=synchronization,
# -> 1484       aggregation=aggregation)
#    1485
#    1486
#
# ...

# %%
# Out:
# Text(0.5,1,'(b) Relu')
